# %%
import mumokepy as mumky
from importlib import reload
import matplotlib.pyplot as plt
reload(mumky)
folder = r'C:\Users\jc2713\OneDrive - Imperial College London (1)\Tohoku - pump priming\Data\muMOKE\241007-J-OOP05-CoPt5x'

files = [r'J-OOP05-AlSiO2-CoPt5x-E0-dose1',
         r'J-OOP05-AlSiO2-CoPt5x-E1-dose1',
         r'J-OOP05-AlSiO2-CoPt5x-E2-dose1',
         r'J-OOP05-AlSiO2-CoPt5x-E3-dose1',
         r'J-OOP05-AlSiO2-CoPt5x-E4-dose1',
         r'J-OOP05-AlSiO2-CoPt5x-E5-dose1',
         r'J-OOP05-AlSiO2-CoPt5x-E6-dose1',
         r'J-OOP05-AlSiO2-CoPt5x-E7-dose1',
         r'J-OOP05-AlSiO2-CoPt5x-E8-dose1']



arrays = {}
for i, file in enumerate(files):
    arrays[i] = mumky.MOKEAnalyzer(material= 'CoPt5x', sample_name= 'J-OOP5', array_name = 'E'+str(i), filename = file+'.csv', folder=folder)
    arrays[i].read_data()
    #print(arrays[i].data)
    arrays[i].analyze(field_threshold = 2000)
    fig,ax = plt.subplots(1,1)
    arrays[i].plot_data(ax)
# Out:
# c:\Users\jc2713\OneDrive - Imperial College London\Documents\GitHub\SendaiLab\muMOKE\mumokepy.py:82: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   self.data = pd.read_csv(self.path, header=31, skipfooter=2002, encoding='latin1')
# c:\Users\jc2713\OneDrive - Imperial College London\Documents\GitHub\SendaiLab\muMOKE\mumokepy.py:82: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   self.data = pd.read_csv(self.path, header=31, skipfooter=2002, encoding='latin1')
#              H   Theta k  H Signal   M Signal  A-B Signal  A+B Signal
# 0     5013.170  0.010232  2.788127   1.344636    0.470595    0.349979
# 1     5013.017  0.010476  2.788483   1.344633    0.470725    0.350077
# 2     5010.950  0.010754  2.787510   1.345368    0.471244    0.350271
# ...

# %%
reload(mumky)
input_folder = r'C:\Users\jc2713\OneDrive - Imperial College London (1)\Tohoku - pump priming\Data\muMOKE\241007-J-OOP05-CoPt5x\Dose1-Erow'
output_folder = r'C:\Users\jc2713\OneDrive - Imperial College London (1)\Tohoku - pump priming\Data\muMOKE\241007-J-OOP05-CoPt5x\Dose1-Erow-output'
erow_batch = mumky.BatchProcessor(input_folder, output_folder)
erow_batch.run_batch_analysis(field_threshold = 2000)
# Out:
# c:\Users\jc2713\OneDrive - Imperial College London\Documents\GitHub\SendaiLab\muMOKE\mumokepy.py:83: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   self.data = pd.read_csv(self.path, header=31, skipfooter=2002, encoding='latin1')
# Index(['H', 'Theta k', 'H Signal', ' M Signal', 'A-B Signal', 'A+B Signal',
#        'M', 'M Smooth'],
#       dtype='object')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\jc2713\OneDrive - Imperial College London\Documents\GitHub\SendaiLab\muMOKE\mumokepy.py:227, in MOKEAnalyzer.analyze(self, field_threshold, window_length, polyorder)
#     226     self.calculate_coercive_field()
# --> 227     self.calculate_saturation_magnetization()
#     228 except Exception as e:
#
# ...
